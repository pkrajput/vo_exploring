# %%
# %env LC_ALL=C.UTF-8
# %env LANG=C.UTF-8
# Out:
# env: LC_ALL=C.UTF-8
# env: LANG=C.UTF-8

# %%
# !wandb login d7ef4803270409bd52a6b2449d4fd21aeedaf35a
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# %env NVIDIA_VISIBLE_DEVICES=1
# %env CUDA_VISIBLE_DEVICES=6
# Out:
# env: NVIDIA_VISIBLE_DEVICES=1
# env: CUDA_VISIBLE_DEVICES=6

# %%
# !ls ../../

# %%
# !cat train_pose_allrandom_whole_.sh
# Out:
# DATA_ROOT=../..
# TRAIN_SET=$DATA_ROOT/kitti_vo_256
#
# EPOCH_SIZE=1000
#
# python3 ../train.py $TRAIN_SET \
# --resnet-layers 50 \
# --num-scales 1 \
# -b4 -s0.1 -c0.5 --epoch-size $EPOCH_SIZE --sequence-length 3 \
# --with-ssim 1 \
# --with-mask 1 \
# --with-auto-mask 1 \
# --with-pretrain 0 \
# --pretrained-disp ../checkpoints_pretrained/dispnet_model_best.pth.tar \
# --pretrained-pose ../checkpoints_pretrained/exp_pose_model_best.pth.tar \
# --epochs 50 \
# --lr 1e-5 \
# --name coordconv_allrandom_first_all \
# --with-coord-conv 1 \
# --conv1-weight-mode all_random \
# --fine-tune-mode whole \
# --use-scheduler 1 \
# --run-id $1 \
# --warmup-lr 1e-10 \
# --warmup-epoch 2 \
# --step-size 10 \
# --gamma-lr .1 \
# --min-lr 1e-10 \
# --print-freq 50 \
# --epoch-size-val 10

# %%
# !ls ../checkpoints_

# %%
! ./train_pose_allrandom_whole_.sh "train_pose_allrandom_whole_"
# Out:
# => will save everything to ../checkpoints_/coordconv_allrandom_first_all/05-26-10:05
# wandb: Currently logged in as: scalyvladimir. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.12.17 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /dpds/ORB_SLAM3/vo_exploring/DL_VO/scripts/wandb/run-20220526_100550-3hflsj03
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train_pose_allrandom_whole_
# wandb:  View project at https://wandb.ai/scalyvladimir/vo_exploring
# wandb:  View run at https://wandb.ai/scalyvladimir/vo_exploring/runs/3hflsj03
# => fetching scenes in '../../kitti_vo_256'
# 32644 samples found in 16 train scenes
# 8138 samples found in 2 valid scenes
# => creating model
# => using model with CoordConv
# => using pre-trained weights for DispResNet
# => using pre-trained weights for PoseResNet
# ...
