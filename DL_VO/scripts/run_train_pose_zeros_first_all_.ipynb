# %%
# !nvidia-smi
# Out:
# Thu May 26 09:10:03 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:06:00.0 Off |                    0 |
# | N/A   33C    P0    58W / 300W |  15903MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
# %env LC_ALL=C.UTF-8
# %env LANG=C.UTF-8
# Out:
# env: LC_ALL=C.UTF-8
# env: LANG=C.UTF-8

# %%
# %env NVIDIA_VISIBLE_DEVICES=1
# %env CUDA_VISIBLE_DEVICES=2
# Out:
# env: NVIDIA_VISIBLE_DEVICES=1
# env: CUDA_VISIBLE_DEVICES=2

# %%
# !ls
# Out:
# Untitled.ipynb			    train_pose_random_whole.sh
# source_scripts			    train_pose_zeros_first_all.sh
# train_pose_allrandom_first_all.sh   train_pose_zeros_whole.sh
# train_pose_allrandom_first_all1.sh  train_resnet50_pose_256.sh
# train_pose_allrandom_whole.sh	    train_runs.ipynb
# train_pose_random_first_all.sh	    wandb

# %%
! ./train_pose_zeros_first_all_.sh "train_pose_zeros_first_all_"
# Out:
# => will save everything to ../checkpoints_/coordconv_zeros_first_all/05-25-16:04
# wandb: Currently logged in as: scalyvladimir. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.16
# wandb: Run data is saved locally in /dpds/ORB_SLAM3/vo_exploring/DL_VO/scripts/wandb/run-20220525_160443-2hyfgqbr
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train_pose_zeros_first_all_
# wandb: ������ View project at https://wandb.ai/scalyvladimir/vo_exploring
# wandb: ���� View run at https://wandb.ai/scalyvladimir/vo_exploring/runs/2hyfgqbr
# => fetching scenes in '../../kitti_vo_256'
# 32644 samples found in 16 train scenes
# 8138 samples found in 2 valid scenes
# => creating model
# => using model with CoordConv
# => using pre-trained weights for DispResNet
# => using pre-trained weights for PoseResNet
# => setting adam solver for PoseResNet only
# => using lr scheduler StepLRWithWarmup
# ...
